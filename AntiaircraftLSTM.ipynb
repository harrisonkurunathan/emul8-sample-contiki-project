# %% [markdown]
# <a href="https://colab.research.google.com/github/harrisonkurunathan/emul8-sample-contiki-project/blob/master/AntiaircraftLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def simulate_movement(num_missiles, num_steps):
    movements = []
    for _ in range(num_missiles):
        missile_x, missile_y = np.random.rand(2) * 100  # Random initial position for missile
        aircraft_x, aircraft_y = np.random.rand(2) * 100  # Random initial position for aircraft
        trajectory = []
        for _ in range(num_steps):
            trajectory.append([missile_x, missile_y, aircraft_x, aircraft_y])
            missile_x += (aircraft_x - missile_x) * 0.1  # Missile moves towards the aircraft
            missile_y += (aircraft_y - missile_y) * 0.1
            aircraft_x += (np.random.rand() - 0.5) * 2  # Random movement in x for aircraft
            aircraft_y += (np.random.rand() - 0.5) * 2  # Random movement in y for aircraft
        movements.append(trajectory)
    return np.array(movements)

num_missiles = 10
num_steps = 100
data = simulate_movement(num_missiles, num_steps)

for missile in data:
    plt.plot(missile[:, 0], missile[:, 1], marker='o', label='Missile')
    plt.plot(missile[:, 2], missile[:, 3], marker='x', label='Aircraft')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.title('Missile and Aircraft Movements')
#plt.legend()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

def prepare_data(data, time_steps):
    X, y = [], []
    for movement in data:
        for i in range(len(movement) - time_steps):
            X.append(movement[i:i+time_steps, :4])
            y.append(movement[i+time_steps, :2])  # Predict missile position
    return np.array(X), np.array(y)

time_steps = 5
X, y = prepare_data(data, time_steps)

scaler_X = MinMaxScaler()
X = scaler_X.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)

scaler_y = MinMaxScaler()
y = scaler_y.fit_transform(y)

print("Input shape:", X.shape)
print("Output shape:", y.shape)
# Out:
# Input shape: (950, 5, 4)
# Output shape: (950, 2)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(50, input_shape=(time_steps, 4)))
model.add(Dense(2))
model.compile(optimizer='adam', loss='mse')

history = model.fit(X, y, epochs=100, batch_size=64, validation_split=0.2)

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 12/12 [==============================] - 3s 52ms/step - loss: 0.1647 - val_loss: 0.0826
# Epoch 2/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0262 - val_loss: 0.0107
# Epoch 3/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.0022
# Epoch 4/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0039
# Epoch 5/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 8.9289e-04
# Epoch 6/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 7.6302e-04
# Epoch 7/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 8/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 8.9275e-04
# Epoch 9/100
# 12/12 [==============================] - 0s 8ms/step - loss: 9.5747e-04 - val_loss: 8.3472e-04
# Epoch 10/100
# 12/12 [==============================] - 0s 8ms/step - loss: 8.5936e-04 - val_loss: 8.3111e-04
# Epoch 11/100
# 12/12 [==============================] - 0s 8ms/step - loss: 7.8475e-04 - val_loss: 7.4738e-04
# Epoch 12/100
# 12/12 [==============================] - 0s 6ms/step - loss: 7.2397e-04 - val_loss: 8.3864e-04
# Epoch 13/100
# 12/12 [==============================] - 0s 8ms/step - loss: 6.5832e-04 - val_loss: 6.8042e-04
# Epoch 14/100
# 12/12 [==============================] - 0s 11ms/step - loss: 5.9730e-04 - val_loss: 6.9489e-04
# Epoch 15/100
# 12/12 [==============================] - 0s 9ms/step - loss: 5.5282e-04 - val_loss: 7.2572e-04
# Epoch 16/100
# 12/12 [==============================] - 0s 7ms/step - loss: 5.1014e-04 - val_loss: 6.2051e-04
# Epoch 17/100
# 12/12 [==============================] - 0s 8ms/step - loss: 4.7168e-04 - val_loss: 6.4150e-04
# Epoch 18/100
# 12/12 [==============================] - 0s 7ms/step - loss: 4.3925e-04 - val_loss: 5.7002e-04
# Epoch 19/100
# 12/12 [==============================] - 0s 7ms/step - loss: 4.0376e-04 - val_loss: 5.3521e-04
# Epoch 20/100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.7325e-04 - val_loss: 4.8358e-04
# Epoch 21/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4757e-04 - val_loss: 5.2307e-04
# Epoch 22/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.2006e-04 - val_loss: 4.7078e-04
# Epoch 23/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.9272e-04 - val_loss: 4.5768e-04
# Epoch 24/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7088e-04 - val_loss: 3.8665e-04
# Epoch 25/100
# 12/12 [==============================] - 0s 10ms/step - loss: 2.4473e-04 - val_loss: 3.7310e-04
# Epoch 26/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.2583e-04 - val_loss: 3.0343e-04
# Epoch 27/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.0188e-04 - val_loss: 3.0883e-04
# Epoch 28/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8547e-04 - val_loss: 2.6507e-04
# Epoch 29/100
# 12/12 [==============================] - 0s 6ms/step - loss: 1.6747e-04 - val_loss: 2.4616e-04
# Epoch 30/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4922e-04 - val_loss: 2.2831e-04
# Epoch 31/100
# 12/12 [==============================] - 0s 9ms/step - loss: 1.3238e-04 - val_loss: 2.2093e-04
# Epoch 32/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1913e-04 - val_loss: 2.0234e-04
# Epoch 33/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.0576e-04 - val_loss: 1.8164e-04
# Epoch 34/100
# 12/12 [==============================] - 0s 8ms/step - loss: 9.4676e-05 - val_loss: 1.7740e-04
# Epoch 35/100
# 12/12 [==============================] - 0s 10ms/step - loss: 8.2724e-05 - val_loss: 1.3131e-04
# Epoch 36/100
# 12/12 [==============================] - 0s 7ms/step - loss: 7.4022e-05 - val_loss: 1.2412e-04
# Epoch 37/100
# 12/12 [==============================] - 0s 8ms/step - loss: 6.5279e-05 - val_loss: 1.1933e-04
# Epoch 38/100
# 12/12 [==============================] - 0s 7ms/step - loss: 5.6895e-05 - val_loss: 1.0348e-04
# Epoch 39/100
# 12/12 [==============================] - 0s 8ms/step - loss: 5.0400e-05 - val_loss: 9.2391e-05
# Epoch 40/100
# 12/12 [==============================] - 0s 7ms/step - loss: 4.4972e-05 - val_loss: 8.1039e-05
# Epoch 41/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.9394e-05 - val_loss: 7.0669e-05
# Epoch 42/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4633e-05 - val_loss: 6.0951e-05
# Epoch 43/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.0856e-05 - val_loss: 5.7001e-05
# Epoch 44/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7411e-05 - val_loss: 5.6094e-05
# Epoch 45/100
# 12/12 [==============================] - 0s 11ms/step - loss: 2.4415e-05 - val_loss: 5.2778e-05
# Epoch 46/100
# 12/12 [==============================] - 0s 9ms/step - loss: 2.3692e-05 - val_loss: 5.9516e-05
# Epoch 47/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.0477e-05 - val_loss: 4.7398e-05
# Epoch 48/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7963e-05 - val_loss: 4.5889e-05
# Epoch 49/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7027e-05 - val_loss: 4.6411e-05
# Epoch 50/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.5506e-05 - val_loss: 4.2269e-05
# Epoch 51/100
# 12/12 [==============================] - 0s 9ms/step - loss: 1.4802e-05 - val_loss: 4.4149e-05
# Epoch 52/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.4176e-05 - val_loss: 3.8339e-05
# Epoch 53/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2619e-05 - val_loss: 2.8235e-05
# Epoch 54/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.
100
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7567e-06 - val_loss: 1.7226e-05
# Epoch 85/100
# 12/12 [==============================] - 0s 9ms/step - loss: 6.5745e-06 - val_loss: 1.2888e-05
# Epoch 86/100
# 12/12 [==============================] - 0s 8ms/step - loss: 6.5678e-06 - val_loss: 1.7892e-05
# Epoch 87/100
# 12/12 [==============================] - 0s 7ms/step - loss: 6.5832e-06 - val_loss: 1.6497e-05
# Epoch 88/100
# 12/12 [==============================] - 0s 7ms/step - loss: 6.6721e-06 - val_loss: 1.1570e-05
# Epoch 89/100
# 12/12 [==============================] - 0s 9ms/step - loss: 6.4866e-06 - val_loss: 1.6770e-05
# Epoch 90/100
# 12/12 [==============================] - 0s 7ms/step - loss: 6.5108e-06 - val_loss: 1.2762e-05
# Epoch 91/100
# 12/12 [==============================] - 0s 6ms/step - loss: 6.4084e-06 - val_loss: 1.3259e-05
# Epoch 92/100
# 12/12 [==============================] - 0s 7ms/step - loss: 6.1980e-06 - val_loss: 1.8170e-05
# Epoch 93/100
# 12/12 [==============================] - 0s 8ms/step - loss: 6.2997e-06 - val_loss: 1.2707e-05
# Epoch 94/100
# 12/12 [==============================] - 0s 12ms/step - loss: 6.0757e-06 - val_loss: 1.5388e-05
# Epoch 95/100
# 12/12 [==============================] - 0s 15ms/step - loss: 6.0638e-06 - val_loss: 1.4393e-05
# Epoch 96/100
# 12/12 [==============================] - 0s 11ms/step - loss: 6.0000e-06 - val_loss: 1.4460e-05
# Epoch 97/100
# 12/12 [==============================] - 0s 9ms/step - loss: 5.8953e-06 - val_loss: 1.3809e-05
# Epoch 98/100
# 12/12 [==============================] - 0s 11ms/step - loss: 5.8742e-06 - val_loss: 1.7490e-05
# Epoch 99/100
# 12/12 [==============================] - 0s 9ms/step - loss: 6.0889e-06 - val_loss: 1.2967e-05
# Epoch 100/100
# 12/12 [==============================] - 0s 12ms/step - loss: 6.3258e-06 - val_loss: 1.0777e-05

# %%
def predict_future_positions(model, initial_positions, time_steps, future_steps):
    future_positions = initial_positions.copy()
    for _ in range(future_steps):
        input_data = future_positions[-time_steps:]
        input_data = scaler_X.transform(input_data)
        input_data = input_data[np.newaxis, ...]
        next_position = model.predict(input_data)
        next_position = scaler_y.inverse_transform(next_position)
        # Ensure next_position has the correct dimensions
        next_position = next_position.reshape(1, 2)
        future_positions = np.vstack([future_positions, np.hstack([next_position, future_positions[-1, 2:].reshape(1, 2)])])
    return future_positions

missile_index = 0
initial_positions = data[missile_index][:time_steps]
predicted_positions = predict_future_positions(model, initial_positions, time_steps, num_steps-time_steps)

plt.figure(figsize=(10, 6))
plt.plot(data[missile_index][:, 0], data[missile_index][:, 1], marker='o', linestyle='-', label='Actual Missile', color='blue')
plt.plot(data[missile_index][:, 2], data[missile_index][:, 3], marker='x', linestyle='-', label='Actual Aircraft', color='green')
plt.plot(predicted_positions[:, 0], predicted_positions[:, 1], marker='x', linestyle='--', label='Predicted Missile', color='red')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.title('Missile and Aircraft Movements (Actual vs Predicted)')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
